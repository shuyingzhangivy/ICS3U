# %%
choose = int(input("you can choose 1,2 or 3 to see the population in20 years, or the Bar charts and line charts"))
#Get the number entered by the user
import numpy as np
#Import the NumPy library and name it np
import matplotlib.pyplot as plt
#Import pyplot from the Matplotlib library and name it plt
if choose == 1:
  the_list = [10000, 12000, 15000, 18000, 20000, 22000, 5000, 28000, 31000, 34000, 37000, 40000, 43000, 46000, 49000, 52000, 55000, 58000, 61000, 64000, 67000, 70000, 73000, 76000, 79000, 82000, 85000, 88000, 91000, 94000, 97000, 100000, 103000, 106000, 109000, 112000, 115000, 118000, 121000, 124000, 127000, 130000, 133000, 136000, 139000, 142000, 145000, 148000, 151000, 154000, 157000, 160000, 163000, 166000, 169000, 172000, 175000, 178000, 181000, 184000, 187000, 190000, 193000, 196000, 199000, 202000, 205000, 208000, 211000, 214000, 217000, 220000, 223000, 226000, 229000, 232000, 235000, 238000, 241000, 244000, 247000, 250000, 253000, 256000, 259000, 262000, 265000, 268000, 271000, 274000, 277000, 280000, 283000, 286000, 289000, 292000, 295000, 298000, 301000, 304000, 307000]
  future_years = [20]
  slope, intercepy = np.polyfit(range(len(the_list)),the_list,1)
  future_population = [slope * day + intercept for day in future_years]
  print("the population in 20 years:", future_population)
elif choose == 2:
  years = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100])
  population = np.array([10000, 12000, 15000, 18000, 20000, 22000, 25000, 28000, 31000, 34000, 37000, 40000, 43000, 46000, 49000, 52000, 55000, 58000, 61000, 64000, 67000, 70000, 73000, 76000, 79000, 82000, 85000, 88000, 91000, 94000, 97000, 100000, 103000, 106000, 109000, 112000, 115000, 118000, 121000, 124000, 127000, 130000, 133000, 136000, 139000, 142000, 145000, 148000, 151000, 154000, 157000, 160000, 163000, 166000, 169000, 172000, 175000, 178000, 181000, 184000, 187000, 190000, 193000, 196000, 199000, 202000, 205000, 208000, 211000, 214000, 217000, 220000, 223000, 226000, 229000, 232000, 235000, 238000, 241000, 244000, 247000, 250000, 253000, 256000, 259000, 262000, 265000, 268000, 271000, 274000, 277000, 280000, 283000, 286000, 289000, 292000, 295000, 298000, 301000, 304000, 307000])
  plt.bar(years, population)
  plt.xlabel('Year')
  plt.ylabel('Population')
  plt.show()

elif choose == 3:
  years = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100])
  population = np.array([10000, 12000, 15000, 18000, 20000, 22000, 25000, 28000, 31000, 34000, 37000, 40000, 43000, 46000, 49000, 52000, 55000, 58000, 61000, 64000, 67000, 70000, 73000, 76000, 79000, 8200, 85000, 88000, 91000, 94000, 97000, 100000, 103000, 106000, 109000, 112000, 115000, 118000, 121000, 124000, 127000, 130000, 133000, 136000, 139000, 142000, 145000, 148000, 151000, 154000, 157000, 160000, 163000, 166000, 169000, 172000, 175000, 178000, 181000, 184000, 187000, 190000, 193000, 196000, 199000, 202000, 205000, 208000, 211000, 214000, 217000, 220000, 223000, 226000, 229000, 232000, 235000, 238000, 241000, 244000, 247000, 250000, 253000, 256000, 259000, 262000, 265000, 268000, 271000, 274000, 277000, 280000, 283000, 286000, 289000, 292000, 295000, 298000, 301000, 304000, 307000])
  plt.plot(years, population)
  plt.xlabel('Year')
  plt.ylabel('Population')
  plt.show()

else:
  print("please choose again.")
# Out:
# you can choose 1,2 or 3 to see the population in20 years, or the Bar charts and line charts2

# %% [markdown]
# np.polyfit() is an instruction in python for fitting a primary polynomial,
# range(len(the_list)) to make an array of the same length as the_list from 0 to len(the_list)-1.
# the_list, are the data points to be fitted.
# 1 is the number of times the polynomial is fitted
#
# Loop through each element in "future_years", and in each iteration, calculate the population count corresponding to each element using "slope * day + intercept".
#
# in choose 2, Create arrays for years and population, then add horizontal and vertical axis labels using “plt.label”, and finally command it to plot the graph.
#
# choose 3 same as choose two.
