poem_meaningful = ["Tomorrow's Shore - Clara Bennett ‘Today's waves crash, but do not fear, For dawn brings hope, ever near. Embrace the tides, both rise and fall, Your spirit strong, will conquer all.’", "Inner Compass—by Jonathan Hayes ‘The storm may rage, the night may call, Yet deep within, you stand tall. Listen close to the silent voice, It guides you through, your inner choice.’", "Whispered Hope—by Laura Whitman ‘In the quiet of your deepest night, Whispered hope will bring you light. Amid the chaos, find your calm, Let your heart be your guiding psalm. Though lost you feel, and far adrift, Your inner strength will give a lift. With every step, with every breath, You'll navigate life's path to death.’", "Rising Dawn—by Olivia Hart ‘When shadows fall and dreams seem lost, Hold on through the tempest's cost. For after night, the dawn will rise, A new beginning in the skies. The darkest hour, just before light, Gives way to hope, banishing fright. Each new sunrise brings a chance, To forge ahead, to join the dance.’"]
poem_feelsad = [poem_happy, poem_uplifting]

#These are for the quotes.
quote_empowering = ["‘Your future is yours to create, be brave and follow your dreams, don't be afraid to fail.’ - Mel Gibson", "‘Success is not the end, failure is not the end, courage is eternal.’ --Winston Churchill", "‘Every stage of life has its beauty, and forty is only the beginning of a new one.’ - Charles Dickens", "‘Experience is the best teacher, and at forty you have a wealth of wisdom and experience.’ - William James"]
quote_sad = ["‘Grief flows against the river, the past is like the wind, and the hurt will eventually be washed away by time.’ --Si Murong", "‘Every goodbye is a sharp pain in the heart.’ --James Joyce", "‘Grief sometimes makes one stronger, for in pain we learn how to endure.’ --Helen Keller", "‘Loss doesn't come back, but we can learn to live with it.’ --Haruki Murakami"]
quote_emotional = ["‘Love is a meeting, not a search.’ --Toni Morrison", "‘Sometimes love doesn't just rely on time to measure it, but understanding and acceptance of each other.’ --Margaret Mitchell", "‘True love is not perfect, but tolerant of faults.’ --Marcel Proust", "‘The essence of love is that it gently changes one another without you realizing it.’ --Nicholas Sparks", "‘Don't cry because it's over, smile because it happened.’ - Dr. Suess"]
quote_funny = ["‘Life is like a box of chocolates, you never know what you're going to get.’ --Forrest Gump", "‘I know what I care about, I just don't know why I care.’ --The Big Bang Theory", "‘No, I'm not losing my mind, I'm just finding my happiness.’ --Beauty and the Beast", "‘My life is like a TV show, but without the commercials, so I don't know when it's time to go to the bathroom.’ --Friends"]

#These quotes are for the age question.
quote_child = [quote_funny]
quote_young_adult = [quote_funny, quote_empowering]
quote_adult = [quote_empowering, quote_emotional, quote_sad]
quote_old_adult = [quote_funny, quote_emotional, quote_empowering]

#We set a while True so that if the user inputs a inncorrect input the code will repeat itself.
while True:
  def asking_question_one():
    #This asks if they want a poem or a quote
    question_one = input("Do you want a 'poem' or a 'inspirational quote' You wrote: ")
    #This changes the input from uppercase to lowercase.
    question_one = (str.lower(question_one))
    #The below if/elif replace some of the possible inputs like "inspirational" and "inspirational quote" with quote
    if question_one == 'inspirational quote':
      question_one = 'quote'
    elif question_one == 'inspirational':
      question_one = 'quote'
    return question_one
  question_one = asking_question_one()
  #This checks
  if question_one not in ['poem', 'quote']:
    clear_output()
  else:
    if question_one == 'poem':
        question_two = input("Do you want a poem based off of how you are currently 'Feeling', or do you want a 'Specific' type of poem? You wrote: ")
        question_two = (str.lower(question_two))
        if question_two == 'feeling':
          question_three = input("How do you feel? 'Happy' 'Sad' 'Angry' 'Depressed' 'Lost' You wrote: ")
          question_three = (str.lower(question_three))
          if question_three not in ['happy', 'sad', 'angry', 'depressed', 'lost']:
            clear_output()
          else:
            key = (question_one + question_two + question_three)
            break
        elif question_two == 'specific':
          question_three = input("What kind of peom do you want? 'Happy' 'Sad' 'up lifting' 'Meaningful' You wrote: ")
          question_three = (str.lower(question_three))
          if question_three not in ['happy', 'sad', 'up lifting', 'meaningful']:
            clear_output()
          else:
            key = (question_one + question_two + question_three)
            break
        else:
          clear_output()

    elif question_one == 'quote':
      question_two = input("Do you want a quote based off of your 'Age', or do you want a 'Specific' type of quote? You wrote:")
      question_two = (str.lower(question_two))
      if question_two == 'age':
        question_three = int(input("How old are you? (Please write your input in number form) You wrote: "))
        key = (question_one + question_two)
        break
      elif question_two == 'specific':
        question_three = input("Do you want a quote that is 'empowering' 'sad' 'emotional' or 'funny' You wrote: ")
        question_three = (str.lower(question_three))
        if question_three not in ['empowering', 'sad', 'emotional', 'funny']:
          clear_output()
        else:
          key = (question_one + question_two + question_three)
          break
      else:
        clear_output()

if (key == "poemfeelinghappy" or key == "poemfeelingangry" or key == "poemspecifichappy"):
  ran = random.choice (poem_happy)
elif (key == "poemfeelingsad"):
  ran = random.choice (poem_feelsad)
elif (key == "poemfeelingdepressed" or key == "poemspecificup lifting"):
  ran = random.choice (poem_uplifting)
elif (key == "poemfeelinglost" or key == "poemspecificmeaningful"):
  ran = random.choice (poem_meaningful)
elif (key == "poemspecificsad"):
  ran = random.choice (poem_sad)
elif (key == "quotespecificempowering"):
  ran = random.choice (quote_empowering)
elif (key == "quotespecificsad"):
  ran = random.choice (quote_sad)
elif (key == "quotespecificemotional"):
  ran = random.choice (quote_emotional)
elif (key == "quotespecificfunny"):
  ran = random.choice (quote_funny)
elif (key == "quoteage"):
  if question_three <= 12:
    ran = random.choice (quote_child)
  elif question_three <= 20:
    ran = random.choice (quote_young_adult)
  elif question_three <= 40:
    ran = random.choice (quote_adult)
  elif question_three >= 41:
    ran = random.choice (quote_old_adult)

if question_two == "age":
  print("Printing poem based on the age " + question_two + ": ")
  print(ran)
else:
  print("Printing " + question_three + " " + question_one + ": ")
  print(ran)

# %% [markdown]
# Possible keys:
#
# _
#
# poemfeelinghappy | poemfeelingsad | poemfeelingangry | poemfeelingdepressed | poemfeelingexcited | poemfeelinglost
#
# _
#
# poemspecifichappy | poemspecificsad | poemspecificup lifting | poemspecificexciting | poemspecificmeaningful
#
# _
#
# quoteage
#
# _
#
# quotespecificempowering | quotespecificsad | quotespecificemotional | quotespecificfunny
